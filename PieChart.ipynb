# %% [markdown]
# <a href="https://colab.research.google.com/github/Arpan-000/PlayingWithPythonModule/blob/main/PieChart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
budget = pd.read_csv("Budget 2.csv")

# %%
print(budget)
# Out:
#   DateofIncome  Income DateofExpense  ReasonofExpense  Expense  Unnamed: 5  \
# 0     11/10/23  1000.0      11/10/23  Transportation       100         NaN
# 1     11/10/23  1000.0      11/10/23            Dmart      730         NaN
# 2     12/10/23  1000.0      12/10/23         Medicine      380         NaN
# 3          NaN     NaN      12/10/23        Vegetable       70         NaN
# 4          NaN     NaN      12/10/23  Transportation       100         NaN
# 5          NaN     NaN      12/10/23             Milk       80         NaN
# 6          NaN     NaN      12/10/23           Others       70         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN

# %%
data= budget.Expense
keys = budget.ReasonofExpense

palette_color = sns.color_palette('bright')

plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab043803340>,
# ...
#  [Text(1.076892487035583, 0.22428234742466285, 'Transportation '),
#   Text(-0.3655903070444223, 1.0374698681866212, 'Dmart'),
#   Text(-0.5499999702695119, -0.9526279613277874, 'Medicine'),
#   Text(0.42876449572335384, -1.0129960548822972, 'Vegetable'),
#   Text(0.7493719000839002, -0.8052588126587906, 'Transportation '),
#   Text(0.9896615278017795, -0.48017711356232684, 'Milk'),
#   Text(1.0886570128689796, -0.15756239504142588, 'Others')],
#  [Text(0.5873959020194087, 0.1223358258679979, '7%'),
#   Text(-0.19941289475150306, 0.5658926553745206, '48%'),
#   Text(-0.29999998378337006, -0.5196152516333385, '25%'),
#   Text(0.23387154312182934, -0.5525433026630712, '5%'),
#   Text(0.40874830913667276, -0.4392320796320676, '7%'),
#   Text(0.5398153788009705, -0.2619147892158146, '5%'),
#   Text(0.5938129161103525, -0.08594312456805046, '5%')])

# %%
data= budget.Expense
keys = budget.DateofExpense

palette_color = sns.color_palette('muted')

plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab04372a0e0>,
# ...
#  [Text(1.076892487035583, 0.22428234742466285, '11/10/23'),
#   Text(-0.3655903070444223, 1.0374698681866212, '11/10/23'),
#   Text(-0.5499999702695119, -0.9526279613277874, '12/10/23'),
#   Text(0.42876449572335384, -1.0129960548822972, '12/10/23'),
#   Text(0.7493719000839002, -0.8052588126587906, '12/10/23'),
#   Text(0.9896615278017795, -0.48017711356232684, '12/10/23'),
#   Text(1.0886570128689796, -0.15756239504142588, '12/10/23')],
#  [Text(0.5873959020194087, 0.1223358258679979, '7%'),
#   Text(-0.19941289475150306, 0.5658926553745206, '48%'),
#   Text(-0.29999998378337006, -0.5196152516333385, '25%'),
#   Text(0.23387154312182934, -0.5525433026630712, '5%'),
#   Text(0.40874830913667276, -0.4392320796320676, '7%'),
#   Text(0.5398153788009705, -0.2619147892158146, '5%'),
#   Text(0.5938129161103525, -0.08594312456805046, '5%')])
